# %% [markdown]
# # AB ratio Test

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from statsmodels.stats.proportion import proportions_ztest

# %%
import numpy as np
succes_count = np.array([300, 250])
view_count = np.array([1000,1100])

# %%
proportions_ztest(count=succes_count, nobs=view_count)
# p value reddedilir.
# Out:
# (3.7857863233209255, 0.0001532232957772221)
