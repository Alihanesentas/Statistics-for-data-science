# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np

# %%
sample = np.array([17, 160, 234, 149, 145, 107, 197, 75, 201, 225, 211, 119, 
              157, 145, 127, 244, 163, 114, 145,  65, 112, 185, 202, 146,
              203, 224, 203, 114, 188, 156, 187, 154, 177, 95, 165, 50, 110, 
              216, 138, 151, 166, 135, 155, 84, 251, 173, 131, 207, 121, 120])

# %%
sample[0:10]
# Out:
# array([ 17, 160, 234, 149, 145, 107, 197,  75, 201, 225])

# %%
import scipy.stats as stats

# %%
stats.describe(sample)
# Out:
# DescribeResult(nobs=50, minmax=(17, 251), mean=154.38, variance=2578.0363265306123, skewness=-0.32398897278694483, kurtosis=-0.05849823498415985)

# %%
#normality assumption
import pandas as pd

# %%
pd.DataFrame(sample).plot.hist();

# %%
import pylab

# %%
stats.probplot(sample, dist="norm", plot=pylab)
pylab.show();

# %%
# Shpiro-Wilk test

# %%
# H0: Örnek dağılım ile teorik dağılım arasında anlamlı bir fark yoktur.
# H1: Örnek dağılım ile teorik dağılım arasında anlamlı bir fark vardır.

# %%
from scipy.stats import shapiro

# %%
shapiro(sample)
# Out:
# ShapiroResult(statistic=0.985310435295105, pvalue=0.7848682403564453)

# %%
# H0 hipotezi reddedilemez. Yani örnek dağılım ile teorik dağılım arasında anlamlı bir fark yoktur.

# %%
# Single sample t test

# %%
stats.ttest_1samp(sample, popmean=170)
# Out:
# TtestResult(statistic=-2.1753117985877966, pvalue=0.03446041519507144, df=49)
