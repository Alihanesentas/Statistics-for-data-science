# %% [markdown]
# # PROBLEM
# >There are 5 steps on the payment screen during the process of adding a product to the site, and one of these steps is questioned.

# %% [markdown]
# ## Details
# * **Each name has a target of 20 seconds, 4 steps are questioned.**
# * **100 samples are taken to test this situation**
# * **Sample standard deviation is 5 seconds. Sample average is 19 seconds.**

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
